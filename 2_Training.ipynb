# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:
# Encoder Model: Used resnet model to encode images to a particular size(256) . Also tried Resnext model - had similar results.
# Decoder Model:
# RNN uses LSTM.
# Input parameters to LSTM include
# 1. encoded image from resnet(final layer tweaked to obtain required input size for LSTM), 2. Embedded word vector for each caption words. 3. size of hidden layer
# Also, there is a linear layer to map hidden layer output to words.
# I did not change the parameters much - I just used the kind of default values embed size 256, batch size 32 , vocab threshold -6(could have been higher), num epochs - 3 (small enough to check the values).
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:**
# I did not change the transform. the transform provided scales, crops, normalizes as required for resnet. Also random flipping transform is used to enhance data and remove bias. So I believe the transformation is good enough.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:**
# In CNN encoder, Resnet model parameters are already trained from imagenet to provide good feature vectors so I only choose to train the final linear layer of resnet.
# In RNN decoder, all layers have to be trained as none of the layers were trained previously
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**
# Adam optimizer generally worked better in all my previous exercises so choose ADAM. I was happy with the final result so did not change.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 32          # batch size
vocab_threshold = 9       # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 256          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
print(total_step)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=1.04s)
# creating index...
#   0%|          | 758/414113 [00:00<01:56, 3537.74it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:35<00:00, 4324.23it/s]
# 12942

# %%
print(len(list(encoder.embed.parameters())))
# Out:
# 2

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/12942], Loss: 4.7748, Perplexity: 118.4833
# Epoch [1/3], Step [200/12942], Loss: 4.5674, Perplexity: 96.29814
# Epoch [1/3], Step [300/12942], Loss: 4.1928, Perplexity: 66.21115
# Epoch [1/3], Step [400/12942], Loss: 3.8101, Perplexity: 45.15510
# Epoch [1/3], Step [500/12942], Loss: 3.8651, Perplexity: 47.70913
# Epoch [1/3], Step [600/12942], Loss: 3.6860, Perplexity: 39.8868
# Epoch [1/3], Step [700/12942], Loss: 3.8444, Perplexity: 46.73226
# Epoch [1/3], Step [800/12942], Loss: 3.4561, Perplexity: 31.6942
# Epoch [1/3], Step [900/12942], Loss: 3.5654, Perplexity: 35.35425
# Epoch [1/3], Step [1000/12942], Loss: 3.4578, Perplexity: 31.7471
# Epoch [1/3], Step [1100/12942], Loss: 3.2077, Perplexity: 24.7215
# Epoch [1/3], Step [1200/12942], Loss: 3.2555, Perplexity: 25.93310
# Epoch [1/3], Step [1300/12942], Loss: 3.4573, Perplexity: 31.73028
# Epoch [1/3], Step [1400/12942], Loss: 3.5982, Perplexity: 36.5337
# Epoch [1/3], Step [1500/12942], Loss: 3.4556, Perplexity: 31.6783
# Epoch [1/3], Step [1600/12942], Loss: 3.3143, Perplexity: 27.5042
# Epoch [1/3], Step [1700/12942], Loss: 3.3581, Perplexity: 28.7342
# Epoch [1/3], Step [1800/12942], Loss: 3.2711, Perplexity: 26.3399
# Epoch [1/3], Step [1900/12942], Loss: 3.2155, Perplexity: 24.9163
# Epoch [1/3], Step [2000/12942], Loss: 3.0809, Perplexity: 21.7769
# Epoch [1/3], Step [2100/12942], Loss: 3.0476, Perplexity: 21.06432
# Epoch [1/3], Step [2200/12942], Loss: 2.9802, Perplexity: 19.6914
# Epoch [1/3], Step [2300/12942], Loss: 3.6235, Perplexity: 37.4703
# Epoch [1/3], Step [2400/12942], Loss: 3.2721, Perplexity: 26.3668
# Epoch [1/3], Step [2500/12942], Loss: 3.0326, Perplexity: 20.7519
# Epoch [1/3], Step [2600/12942], Loss: 2.6768, Perplexity: 14.5381
# Epoch [1/3], Step [2700/12942], Loss: 2.7028, Perplexity: 14.9210
# Epoch [1/3], Step [2800/12942], Loss: 2.9100, Perplexity: 18.3562
# Epoch [1/3], Step [2900/12942], Loss: 2.9304, Perplexity: 18.7359
# Epoch [1/3], Step [3000/12942], Loss: 2.6725, Perplexity: 14.4758
# Epoch [1/3], Step [3100/12942], Loss: 2.7463, Perplexity: 15.5855
# Epoch [1/3], Step [3200/12942], Loss: 3.3713, Perplexity: 29.1163
# Epoch [1/3], Step [3300/12942], Loss: 3.1206, Perplexity: 22.6596
# Epoch [1/3], Step [3400/12942], Loss: 2.9676, Perplexity: 19.4444
# Epoch [1/3], Step [3500/12942], Loss: 3.7922, Perplexity: 44.3552
# Epoch [1/3], Step [3600/12942], Loss: 2.5999, Perplexity: 13.4628
# Epoch [1/3], Step [3700/12942], Loss: 2.5981, Perplexity: 13.43851
# Epoch [1/3], Step [3800/12942], Loss: 3.0786, Perplexity: 21.7269
# Epoch [1/3], Step [3900/12942], Loss: 2.6198, Perplexity: 13.7332
# Epoch [1/3], Step [4000/12942], Loss: 2.8440, Perplexity: 17.1845
# Epoch [1/3], Step [4100/12942], Loss: 2.7334, Perplexity: 15.3845
# Epoch [1/3], Step [4200/12942], Loss: 3.0178, Perplexity: 20.4470
# Epoch [1/3], Step [4300/12942], Loss: 2.5486, Perplexity: 12.7895
# Epoch [1/3], Step [4400/12942], Loss: 2.4914, Perplexity: 12.0777
# Epoch [1/3], Step [4500/12942], Loss: 2.9343, Perplexity: 18.8080
# Epoch [1/3], Step [4600/12942], Loss: 3.0034, Perplexity: 20.1536
# Epoch [1/3], Step [4700/12942], Loss: 2.7007, Perplexity: 14.8900
# Epoch [1/3], Step [4800/12942], Loss: 2.4059, Perplexity: 11.0886
# Epoch [1/3], Step [4900/12942], Loss: 2.9568, Perplexity: 19.2372
# Epoch [1/3], Step [5000/12942], Loss: 2.7462, Perplexity: 15.5833
# Epoch [1/3], Step [5100/12942], Loss: 2.6738, Perplexity: 14.4950
# Epoch [1/3], Step [5200/12942], Loss: 2.6496, Perplexity: 14.1481
# Epoch [1/3], Step [5300/12942], Loss: 2.5180, Perplexity: 12.4038
# Epoch [1/3], Step [5400/12942], Loss: 2.7401, Perplexity: 15.4891
# Epoch [1/3], Step [5500/12942], Loss: 3.0026, Perplexity: 20.1386
# Epoch [1/3], Step [5600/12942], Loss: 2.7704, Perplexity: 15.9647
# Epoch [1/3], Step [5700/12942], Loss: 2.5203, Perplexity: 12.4320
# Epoch [1/3], Step [5800/12942], Loss: 2.5375, Perplexity: 12.6478
# Epoch [1/3], Step [5900/12942], Loss: 2.3479, Perplexity: 10.4635
# Epoch [1/3], Step [6000/12942], Loss: 2.9000, Perplexity: 18.1735
# Epoch [1/3], Step [6100/12942], Loss: 2.3148, Perplexity: 10.1228
# Epoch [1/3], Step [6200/12942], Loss: 2.6329, Perplexity: 13.9143
# Epoch [1/3], Step [6300/12942], Loss: 2.8786, Perplexity: 17.7900
# Epoch [1/3], Step [6400/12942], Loss: 3.2144, Perplexity: 24.8894
# Epoch [1/3], Step [6500/12942], Loss: 2.6508, Perplexity: 14.1658
# Epoch [1/3], Step [6600/12942], Loss: 2.2411, Perplexity: 9.40380
# Epoch [1/3], Step [6700/12942], Loss: 2.1754, Perplexity: 8.80601
# Epoch [1/3], Step [6800/12942], Loss: 2.5706, Perplexity: 13.0739
# Epoch [1/3], Step [6900/12942], Loss: 3.0879, Perplexity: 21.9306
# Epoch [1/3], Step [7000/12942], Loss: 2.4862, Perplexity: 12.0161
# Epoch [1/3], Step [7100/12942], Loss: 2.5077, Perplexity: 12.2765
# Epoch [1/3], Step [7200/12942], Loss: 2.4718, Perplexity: 11.8441
# Epoch [1/3], Step [7300/12942], Loss: 2.6483, Perplexity: 14.1305
# Epoch [1/3], Step [7400/12942], Loss: 2.4574, Perplexity: 11.6745
# Epoch [1/3], Step [7500/12942], Loss: 2.5984, Perplexity: 13.4423
# Epoch [1/3], Step [7600/12942], Loss: 2.5981, Perplexity: 13.4387
# Epoch [1/3], Step [7700/12942], Loss: 2.4691, Perplexity: 11.8116
# Epoch [1/3], Step [7800/12942], Loss: 2.6895, Perplexity: 14.7245
# Epoch [1/3], Step [7900/12942], Loss: 2.7291, Perplexity: 15.31940
# Epoch [1/3], Step [8000/12942], Loss: 2.4020, Perplexity: 11.0452
# Epoch [1/3], Step [8100/12942], Loss: 2.4798, Perplexity: 11.9394
# Epoch [1/3], Step [8200/12942], Loss: 2.2912, Perplexity: 9.88632
# Epoch [1/3], Step [8300/12942], Loss: 2.4652, Perplexity: 11.7664
# Epoch [1/3], Step [8400/12942], Loss: 2.5922, Perplexity: 13.3591
# Epoch [1/3], Step [8500/12942], Loss: 2.4939, Perplexity: 12.1086
# Epoch [1/3], Step [8600/12942], Loss: 2.4678, Perplexity: 11.7961
# Epoch [1/3], Step [8700/12942], Loss: 2.5633, Perplexity: 12.9779
# Epoch [1/3], Step [8800/12942], Loss: 2.6274, Perplexity: 13.8378
# Epoch [1/3], Step [8900/12942], Loss: 2.5570, Perplexity: 12.8968
# Epoch [1/3], Step [9000/12942], Loss: 2.4223, Perplexity: 11.2717
# Epoch [1/3], Step [9100/12942], Loss: 2.5571, Perplexity: 12.8978
# Epoch [1/3], Step [9200/12942], Loss: 2.5282, Perplexity: 12.5305
# Epoch [1/3], Step [9300/12942], Loss: 2.7400, Perplexity: 15.4869
# Epoch [1/3], Step [9400/12942], Loss: 2.3265, Perplexity: 10.2422
# Epoch [1/3], Step [9500/12942], Loss: 2.4586, Perplexity: 11.6882
# Epoch [1/3], Step [9600/12942], Loss: 2.3317, Perplexity: 10.2950
# Epoch [1/3], Step [9700/12942], Loss: 2.6522, Perplexity: 14.1851
# Epoch [1/3], Step [9800/12942], Loss: 2.5520, Perplexity: 12.8334
# Epoch [1/3], Step [9900/12942], Loss: 2.2503, Perplexity: 9.49036
# Epoch [1/3], Step [10000/12942], Loss: 2.3982, Perplexity: 11.0034
# Epoch [1/3], Step [10100/12942], Loss: 2.4494, Perplexity: 11.5810
# Epoch [1/3], Step [10200/12942], Loss: 2.5706, Perplexity: 13.0737
# Epoch [1/3], Step [10300/12942], Loss: 2.7900, Perplexity: 16.2809
# Epoch [1/3], Step [10400/12942], Loss: 2.7865, Perplexity: 16.2248
# Epoch [1/3], Step [10500/12942], Loss: 2.1490, Perplexity: 8.57638
# Epoch [1/3], Step [10600/12942], Loss: 2.3984, Perplexity: 11.0056
# Epoch [1/3], Step [10700/12942], Loss: 2.5855, Perplexity: 13.2698
# Epoch [1/3], Step [10800/12942], Loss: 2.8236, Perplexity: 16.8375
# Epoch [1/3], Step [10900/12942], Loss: 2.7109, Perplexity: 15.0422
# Epoch [1/3], Step [11000/12942], Loss: 2.3941, Perplexity: 10.9580
# Epoch [1/3], Step [11100/12942], Loss: 2.4430, Perplexity: 11.5079
# Epoch [1/3], Step [11200/12942], Loss: 2.2710, Perplexity: 9.68925
# Epoch [1/3], Step [11300/12942], Loss: 2.9296, Perplexity: 18.71989
# Epoch [1/3], Step [11400/12942], Loss: 2.1669, Perplexity: 8.731068
# Epoch [1/3], Step [11500/12942], Loss: 2.1604, Perplexity: 8.67461
# Epoch [1/3], Step [11600/12942], Loss: 2.1606, Perplexity: 8.67655
# Epoch [1/3], Step [11700/12942], Loss: 2.2398, Perplexity: 9.39131
# Epoch [1/3], Step [11800/12942], Loss: 2.2982, Perplexity: 9.95614
# Epoch [1/3], Step [11900/12942], Loss: 3.0776, Perplexity: 21.7058
# Epoch [1/3], Step [12000/12942], Loss: 2.5125, Perplexity: 12.3355
# Epoch [1/3], Step [12100/12942], Loss: 2.7357, Perplexity: 15.4200
# Epoch [1/3], Step [12200/12942], Loss: 2.4660, Perplexity: 11.7748
# Epoch [1/3], Step [12300/12942], Loss: 2.3117, Perplexity: 10.0912
# Epoch [1/3], Step [12400/12942], Loss: 3.0084, Perplexity: 20.2550
# Epoch [1/3], Step [12500/12942], Loss: 2.4754, Perplexity: 11.8866
# Epoch [1/3], Step [12600/12942], Loss: 2.2607, Perplexity: 9.58976
# Epoch [1/3], Step [12700/12942], Loss: 2.3015, Perplexity: 9.98975
# Epoch [1/3], Step [12800/12942], Loss: 2.2326, Perplexity: 9.32425
# Epoch [1/3], Step [12900/12942], Loss: 2.8403, Perplexity: 17.1206
# Epoch [2/3], Step [100/12942], Loss: 2.2781, Perplexity: 9.7581817
# Epoch [2/3], Step [300/12942], Loss: 2.2186, Perplexity: 9.19466
# Epoch [2/3], Step [400/12942], Loss: 2.0380, Perplexity: 7.67524
# Epoch [2/3], Step [500/12942], Loss: 2.4773, Perplexity: 11.9095
# Epoch [2/3], Step [600/12942], Loss: 2.2580, Perplexity: 9.56444
# Epoch [2/3], Step [700/12942], Loss: 2.4176, Perplexity: 11.2193
# Epoch [2/3], Step [800/12942], Loss: 2.3659, Perplexity: 10.6541
# Epoch [2/3], Step [900/12942], Loss: 2.6020, Perplexity: 13.4906
# Epoch [2/3], Step [1000/12942], Loss: 2.5354, Perplexity: 12.6213
# Epoch [2/3], Step [1100/12942], Loss: 2.5513, Perplexity: 12.8237
# Epoch [2/3], Step [1200/12942], Loss: 2.3802, Perplexity: 10.8071
# Epoch [2/3], Step [1300/12942], Loss: 2.5638, Perplexity: 12.9856
# Epoch [2/3], Step [1400/12942], Loss: 2.3440, Perplexity: 10.4233
# Epoch [2/3], Step [1500/12942], Loss: 2.3384, Perplexity: 10.3645
# Epoch [2/3], Step [1600/12942], Loss: 2.6378, Perplexity: 13.9826
# Epoch [2/3], Step [1700/12942], Loss: 2.3810, Perplexity: 10.8159
# Epoch [2/3], Step [1800/12942], Loss: 2.1391, Perplexity: 8.49180
# Epoch [2/3], Step [1900/12942], Loss: 2.9374, Perplexity: 18.8671
# Epoch [2/3], Step [2000/12942], Loss: 2.4533, Perplexity: 11.6272
# Epoch [2/3], Step [2100/12942], Loss: 2.2841, Perplexity: 9.81715
# Epoch [2/3], Step [2200/12942], Loss: 2.3006, Perplexity: 9.97989
# Epoch [2/3], Step [2300/12942], Loss: 2.2361, Perplexity: 9.35643
# Epoch [2/3], Step [2400/12942], Loss: 2.4275, Perplexity: 11.3304
# Epoch [2/3], Step [2500/12942], Loss: 2.5812, Perplexity: 13.2127
# Epoch [2/3], Step [2600/12942], Loss: 2.7451, Perplexity: 15.5657
# Epoch [2/3], Step [2700/12942], Loss: 2.1793, Perplexity: 8.84000
# Epoch [2/3], Step [2800/12942], Loss: 2.1434, Perplexity: 8.52882
# Epoch [2/3], Step [2900/12942], Loss: 2.1863, Perplexity: 8.90202
# Epoch [2/3], Step [3000/12942], Loss: 2.1779, Perplexity: 8.82746
# Epoch [2/3], Step [3100/12942], Loss: 2.2505, Perplexity: 9.49210
# Epoch [2/3], Step [3200/12942], Loss: 2.7972, Perplexity: 16.3991
# Epoch [2/3], Step [3300/12942], Loss: 2.5469, Perplexity: 12.7677
# Epoch [2/3], Step [3400/12942], Loss: 2.1604, Perplexity: 8.67433
# Epoch [2/3], Step [3500/12942], Loss: 2.4471, Perplexity: 11.5544
# Epoch [2/3], Step [3600/12942], Loss: 2.5735, Perplexity: 13.1112
# Epoch [2/3], Step [3700/12942], Loss: 2.1482, Perplexity: 8.56978
# Epoch [2/3], Step [3800/12942], Loss: 2.3663, Perplexity: 10.6574
# Epoch [2/3], Step [3900/12942], Loss: 2.2010, Perplexity: 9.03439
# Epoch [2/3], Step [4000/12942], Loss: 2.9060, Perplexity: 18.2829
# Epoch [2/3], Step [4100/12942], Loss: 2.5673, Perplexity: 13.0312
# Epoch [2/3], Step [4200/12942], Loss: 2.2222, Perplexity: 9.22795
# Epoch [2/3], Step [4300/12942], Loss: 2.2983, Perplexity: 9.95737
# Epoch [2/3], Step [4400/12942], Loss: 2.2635, Perplexity: 9.61656
# Epoch [2/3], Step [4500/12942], Loss: 2.5085, Perplexity: 12.2863
# Epoch [2/3], Step [4600/12942], Loss: 2.5386, Perplexity: 12.6618
# Epoch [2/3], Step [4700/12942], Loss: 2.6451, Perplexity: 14.0844
# Epoch [2/3], Step [4800/12942], Loss: 2.4532, Perplexity: 11.6252
# Epoch [2/3], Step [4900/12942], Loss: 2.2734, Perplexity: 9.71298
# Epoch [2/3], Step [5000/12942], Loss: 2.2848, Perplexity: 9.82364
# Epoch [2/3], Step [5100/12942], Loss: 2.6100, Perplexity: 13.5994
# Epoch [2/3], Step [5200/12942], Loss: 2.2600, Perplexity: 9.58322
# Epoch [2/3], Step [5300/12942], Loss: 2.4730, Perplexity: 11.8577
# Epoch [2/3], Step [5400/12942], Loss: 2.1092, Perplexity: 8.24156
# Epoch [2/3], Step [5500/12942], Loss: 2.1580, Perplexity: 8.65372
# Epoch [2/3], Step [5600/12942], Loss: 2.2172, Perplexity: 9.18155
# Epoch [2/3], Step [5700/12942], Loss: 2.3323, Perplexity: 10.3011
# Epoch [2/3], Step [5800/12942], Loss: 2.2458, Perplexity: 9.44796
# Epoch [2/3], Step [5900/12942], Loss: 2.3224, Perplexity: 10.2000
# Epoch [2/3], Step [6000/12942], Loss: 2.2656, Perplexity: 9.63705
# Epoch [2/3], Step [6100/12942], Loss: 2.2921, Perplexity: 9.89609
# Epoch [2/3], Step [6200/12942], Loss: 2.1100, Perplexity: 8.24849
# Epoch [2/3], Step [6300/12942], Loss: 2.0991, Perplexity: 8.15903
# Epoch [2/3], Step [6400/12942], Loss: 2.5058, Perplexity: 12.2538
# Epoch [2/3], Step [6500/12942], Loss: 2.3437, Perplexity: 10.4202
# Epoch [2/3], Step [6600/12942], Loss: 1.9410, Perplexity: 6.96576
# Epoch [2/3], Step [6700/12942], Loss: 2.1456, Perplexity: 8.54751
# Epoch [2/3], Step [6800/12942], Loss: 2.4972, Perplexity: 12.1488
# Epoch [2/3], Step [6900/12942], Loss: 2.2225, Perplexity: 9.23016
# Epoch [2/3], Step [7000/12942], Loss: 2.2495, Perplexity: 9.48345
# Epoch [2/3], Step [7100/12942], Loss: 2.3511, Perplexity: 10.4975
# Epoch [2/3], Step [7200/12942], Loss: 2.0776, Perplexity: 7.98501
# Epoch [2/3], Step [7300/12942], Loss: 2.3205, Perplexity: 10.1811
# Epoch [2/3], Step [7400/12942], Loss: 2.6005, Perplexity: 13.4706
# Epoch [2/3], Step [7500/12942], Loss: 2.5437, Perplexity: 12.72731
# Epoch [2/3], Step [7600/12942], Loss: 2.8586, Perplexity: 17.4375
# Epoch [2/3], Step [7700/12942], Loss: 2.3013, Perplexity: 9.98713
# Epoch [2/3], Step [7800/12942], Loss: 2.3206, Perplexity: 10.1818
# Epoch [2/3], Step [7900/12942], Loss: 2.3026, Perplexity: 9.99984
# Epoch [2/3], Step [8000/12942], Loss: 2.1142, Perplexity: 8.28267
# Epoch [2/3], Step [8100/12942], Loss: 2.1219, Perplexity: 8.34707
# Epoch [2/3], Step [8200/12942], Loss: 2.3089, Perplexity: 10.0630
# Epoch [2/3], Step [8300/12942], Loss: 2.0799, Perplexity: 8.00357
# Epoch [2/3], Step [8400/12942], Loss: 2.2182, Perplexity: 9.19127
# Epoch [2/3], Step [8500/12942], Loss: 2.3320, Perplexity: 10.2989
# Epoch [2/3], Step [8600/12942], Loss: 1.9547, Perplexity: 7.06214
# Epoch [2/3], Step [8700/12942], Loss: 2.0252, Perplexity: 7.57784
# Epoch [2/3], Step [8800/12942], Loss: 2.8461, Perplexity: 17.2200
# Epoch [2/3], Step [8900/12942], Loss: 2.7606, Perplexity: 15.8099
# Epoch [2/3], Step [9000/12942], Loss: 1.9785, Perplexity: 7.23210
# Epoch [2/3], Step [9100/12942], Loss: 2.3295, Perplexity: 10.2729
# Epoch [2/3], Step [9200/12942], Loss: 2.2399, Perplexity: 9.39292
# Epoch [2/3], Step [9300/12942], Loss: 2.3273, Perplexity: 10.2507
# Epoch [2/3], Step [9400/12942], Loss: 2.3682, Perplexity: 10.6781
# Epoch [2/3], Step [9500/12942], Loss: 2.1655, Perplexity: 8.71883
# Epoch [2/3], Step [9600/12942], Loss: 2.4483, Perplexity: 11.5689
# Epoch [2/3], Step [9700/12942], Loss: 2.4540, Perplexity: 11.6343
# Epoch [2/3], Step [9800/12942], Loss: 2.1378, Perplexity: 8.48108
# Epoch [2/3], Step [9900/12942], Loss: 1.9943, Perplexity: 7.34688
# Epoch [2/3], Step [10000/12942], Loss: 2.6522, Perplexity: 14.1856
# Epoch [2/3], Step [10100/12942], Loss: 2.4158, Perplexity: 11.1982
# Epoch [2/3], Step [10200/12942], Loss: 2.3168, Perplexity: 10.1429
# Epoch [2/3], Step [10300/12942], Loss: 2.2755, Perplexity: 9.73324
# Epoch [2/3], Step [10400/12942], Loss: 2.3185, Perplexity: 10.1608
# Epoch [2/3], Step [10500/12942], Loss: 2.1968, Perplexity: 8.99629
# Epoch [2/3], Step [10600/12942], Loss: 2.2357, Perplexity: 9.35318
# Epoch [2/3], Step [10700/12942], Loss: 2.4362, Perplexity: 11.4291
# Epoch [2/3], Step [10800/12942], Loss: 2.1318, Perplexity: 8.43039
# Epoch [2/3], Step [10900/12942], Loss: 2.1688, Perplexity: 8.74808
# Epoch [2/3], Step [11000/12942], Loss: 2.2833, Perplexity: 9.80861
# Epoch [2/3], Step [11100/12942], Loss: 2.7004, Perplexity: 14.8851
# Epoch [2/3], Step [11200/12942], Loss: 2.3449, Perplexity: 10.4326
# Epoch [2/3], Step [11300/12942], Loss: 2.2160, Perplexity: 9.17073
# Epoch [2/3], Step [11400/12942], Loss: 2.3306, Perplexity: 10.2837
# Epoch [2/3], Step [11500/12942], Loss: 2.2861, Perplexity: 9.83604
# Epoch [2/3], Step [11600/12942], Loss: 2.4447, Perplexity: 11.5269
# Epoch [2/3], Step [11700/12942], Loss: 2.1683, Perplexity: 8.74354
# Epoch [2/3], Step [11800/12942], Loss: 2.1303, Perplexity: 8.41750
# Epoch [2/3], Step [11900/12942], Loss: 2.1411, Perplexity: 8.50848
# Epoch [2/3], Step [12000/12942], Loss: 2.0977, Perplexity: 8.14769
# Epoch [2/3], Step [12100/12942], Loss: 2.1551, Perplexity: 8.62871
# Epoch [2/3], Step [12200/12942], Loss: 2.5243, Perplexity: 12.4821
# Epoch [2/3], Step [12300/12942], Loss: 2.3581, Perplexity: 10.5704
# Epoch [2/3], Step [12400/12942], Loss: 2.1225, Perplexity: 8.35171
# Epoch [2/3], Step [12500/12942], Loss: 2.3342, Perplexity: 10.3210
# Epoch [2/3], Step [12600/12942], Loss: 2.3849, Perplexity: 10.8581
# Epoch [2/3], Step [12700/12942], Loss: 2.5503, Perplexity: 12.8106
# Epoch [2/3], Step [12800/12942], Loss: 1.8846, Perplexity: 6.58399
# Epoch [2/3], Step [12900/12942], Loss: 2.3055, Perplexity: 10.0287
# Epoch [3/3], Step [100/12942], Loss: 2.3390, Perplexity: 10.371205
# Epoch [3/3], Step [200/12942], Loss: 2.2157, Perplexity: 9.16801
# Epoch [3/3], Step [300/12942], Loss: 3.0152, Perplexity: 20.3934
# Epoch [3/3], Step [400/12942], Loss: 2.4365, Perplexity: 11.4331
# Epoch [3/3], Step [500/12942], Loss: 2.2651, Perplexity: 9.63229
# Epoch [3/3], Step [600/12942], Loss: 2.4619, Perplexity: 11.7272
# Epoch [3/3], Step [700/12942], Loss: 2.2178, Perplexity: 9.18740
# Epoch [3/3], Step [800/12942], Loss: 2.2698, Perplexity: 9.67787
# Epoch [3/3], Step [900/12942], Loss: 1.9538, Perplexity: 7.05542
# Epoch [3/3], Step [1000/12942], Loss: 2.5669, Perplexity: 13.0255
# Epoch [3/3], Step [1100/12942], Loss: 2.7795, Perplexity: 16.1105
# Epoch [3/3], Step [1200/12942], Loss: 2.1943, Perplexity: 8.97372
# Epoch [3/3], Step [1300/12942], Loss: 2.1847, Perplexity: 8.88842
# Epoch [3/3], Step [1400/12942], Loss: 1.9181, Perplexity: 6.80839
# Epoch [3/3], Step [1500/12942], Loss: 2.9480, Perplexity: 19.0672
# Epoch [3/3], Step [1600/12942], Loss: 2.2751, Perplexity: 9.72938
# Epoch [3/3], Step [1700/12942], Loss: 2.3912, Perplexity: 10.9268
# Epoch [3/3], Step [1800/12942], Loss: 2.1529, Perplexity: 8.60979
# Epoch [3/3], Step [1900/12942], Loss: 2.2502, Perplexity: 9.48976
# Epoch [3/3], Step [2000/12942], Loss: 2.3451, Perplexity: 10.4343
# Epoch [3/3], Step [2100/12942], Loss: 2.2560, Perplexity: 9.54453
# Epoch [3/3], Step [2200/12942], Loss: 3.1167, Perplexity: 22.5723
# Epoch [3/3], Step [2300/12942], Loss: 2.2711, Perplexity: 9.68962
# Epoch [3/3], Step [2400/12942], Loss: 2.2681, Perplexity: 9.66089
# Epoch [3/3], Step [2500/12942], Loss: 2.2336, Perplexity: 9.33346
# Epoch [3/3], Step [2600/12942], Loss: 2.1705, Perplexity: 8.76247
# Epoch [3/3], Step [2700/12942], Loss: 2.0443, Perplexity: 7.72363
# Epoch [3/3], Step [2800/12942], Loss: 2.5214, Perplexity: 12.4457
# Epoch [3/3], Step [2900/12942], Loss: 2.4564, Perplexity: 11.6622
# Epoch [3/3], Step [3000/12942], Loss: 2.3383, Perplexity: 10.3636
# Epoch [3/3], Step [3100/12942], Loss: 2.2245, Perplexity: 9.24897
# Epoch [3/3], Step [3200/12942], Loss: 2.5324, Perplexity: 12.5840
# Epoch [3/3], Step [3300/12942], Loss: 2.3100, Perplexity: 10.0747
# Epoch [3/3], Step [3400/12942], Loss: 2.0941, Perplexity: 8.11836
# Epoch [3/3], Step [3500/12942], Loss: 3.1539, Perplexity: 23.4262
# Epoch [3/3], Step [3600/12942], Loss: 2.4472, Perplexity: 11.5562
# Epoch [3/3], Step [3700/12942], Loss: 2.3065, Perplexity: 10.0388
# Epoch [3/3], Step [3800/12942], Loss: 2.2628, Perplexity: 9.60979
# Epoch [3/3], Step [3900/12942], Loss: 2.3576, Perplexity: 10.5652
# Epoch [3/3], Step [4000/12942], Loss: 2.1103, Perplexity: 8.25102
# Epoch [3/3], Step [4100/12942], Loss: 2.2379, Perplexity: 9.37395
# Epoch [3/3], Step [4200/12942], Loss: 2.2048, Perplexity: 9.06880
# Epoch [3/3], Step [4300/12942], Loss: 2.2678, Perplexity: 9.65791
# Epoch [3/3], Step [4400/12942], Loss: 2.1486, Perplexity: 8.57268
# Epoch [3/3], Step [4500/12942], Loss: 2.5511, Perplexity: 12.8206
# Epoch [3/3], Step [4600/12942], Loss: 2.3934, Perplexity: 10.9504
# Epoch [3/3], Step [4700/12942], Loss: 2.2474, Perplexity: 9.46263
# Epoch [3/3], Step [4800/12942], Loss: 2.5985, Perplexity: 13.4431
# Epoch [3/3], Step [4900/12942], Loss: 2.4337, Perplexity: 11.4010
# Epoch [3/3], Step [5000/12942], Loss: 2.5020, Perplexity: 12.2071
# Epoch [3/3], Step [5100/12942], Loss: 2.5277, Perplexity: 12.5249
# Epoch [3/3], Step [5200/12942], Loss: 2.2962, Perplexity: 9.93657
# Epoch [3/3], Step [5300/12942], Loss: 2.2107, Perplexity: 9.12258
# Epoch [3/3], Step [5400/12942], Loss: 2.3558, Perplexity: 10.5461
# Epoch [3/3], Step [5500/12942], Loss: 2.2643, Perplexity: 9.62484
# Epoch [3/3], Step [5600/12942], Loss: 2.1778, Perplexity: 8.82665
# Epoch [3/3], Step [5700/12942], Loss: 2.2950, Perplexity: 9.92451
# Epoch [3/3], Step [5800/12942], Loss: 2.3564, Perplexity: 10.5526
# Epoch [3/3], Step [5900/12942], Loss: 2.4647, Perplexity: 11.7596
# Epoch [3/3], Step [6000/12942], Loss: 2.7283, Perplexity: 15.3064
# Epoch [3/3], Step [6100/12942], Loss: 2.4926, Perplexity: 12.0928
# Epoch [3/3], Step [6200/12942], Loss: 3.2140, Perplexity: 24.8791
# Epoch [3/3], Step [6300/12942], Loss: 2.4353, Perplexity: 11.4196
# Epoch [3/3], Step [6400/12942], Loss: 2.0609, Perplexity: 7.85328
# Epoch [3/3], Step [6447/12942], Loss: 2.2674, Perplexity: 9.65410
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-191c08218022> in <module>()
#      54
#      55         # Get training statistics.
# ---> 56         stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
#      57
#      58         # Print training statistics (on same line).
#
# KeyboardInterrupt:

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
